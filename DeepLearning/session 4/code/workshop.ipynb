# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout ,Flatten
from tensorflow.keras import backend as k

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 7s 1us/step

# %%
import matplotlib.pyplot as plt
print("x_train %s sample patch \n:" % (str(x_train.shape)), x_train[1, 15:20, 5:10])
plt.imshow(x_train[1,15:20,5:10], cmap='gray')
#plt.imshow(x_train[1,15:20,5:10],)
#print(str(x_train.shape))
# Out:
# x_train (60000, 28, 28) sample patch
# : [[  0  76 246 252 112]
#  [  0  85 252 230  25]
#  [  0  85 252 223   0]
#  [  0  85 252 145   0]
#  [  0  86 253 225   0]]

# %%
plt.imshow(x_train[1], cmap='gray')
plt.show()

# %%
plt.imshow(x_train[2], cmap='gray')
plt.show()

# %%
import tensorflow as tf
# Load and preprocess the MNIST dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.astype('float32') / 255.0# scaling min max scaler
x_test = x_test.astype('float32') /255.0
#flatten the images (28*28 into 784)
x_train = x_train.reshape(x_train.shape[0], -1)
x_test = x_test.reshape(x_test.shape[0], -1)
#one - hot encoding labels
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(200, activation = 'relu', input_shape =(784,)),
    tf.keras.layers.Dense(100, activation = 'relu'),
    tf.keras.layers.Dense(60, activation = 'relu'),
    tf.keras.layers.Dense(30, activation = 'relu'),
    tf.keras.layers.Dense(10, activation = 'softmax')
])
model.summary()
# Out:
# c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 60)             │         6,060 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 30)             │         1,830 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           310 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 185,300 (723.83 KB)
#  Trainable params: 185,300 (723.83 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 11ms/step - accuracy: 0.9120 - loss: 0.2944 - val_accuracy: 0.9592 - val_loss: 0.1329
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9658 - loss: 0.1124 - val_accuracy: 0.9705 - val_loss: 0.0986
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9771 - loss: 0.0762 - val_accuracy: 0.9706 - val_loss: 0.0958
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9818 - loss: 0.0577 - val_accuracy: 0.9719 - val_loss: 0.1028
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9856 - loss: 0.0467 - val_accuracy: 0.9758 - val_loss: 0.0886
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9879 - loss: 0.0382 - val_accuracy: 0.9721 - val_loss: 0.1015
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9899 - loss: 0.0321 - val_accuracy: 0.9763 - val_loss: 0.0953
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9907 - loss: 0.0278 - val_accuracy: 0.9751 - val_loss: 0.0976
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9924 - loss: 0.0226 - val_accuracy: 0.9726 - val_loss: 0.1124
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9916 - loss: 0.0247 - val_accuracy: 0.9694 - val_loss: 0.1233

# %%
test_loss , test_acc = model.evaluate(x_test,y_test)
print("Test accuracy: ", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9732 - loss: 0.1024
# Test accuracy:  0.9732000231742859

# %%
import numpy as np
def get_random_indecies(total_images,num_images):
    indecies= np.random.choice(total_images, num_images, replace=False)
    return indecies

# %%
predictions = model.predict(x_test)
x_test_images = x_test.reshape(-1,28,28)
predictions_classes = np.argmax(predictions,axis=1)
true_classes = np.argmax(y_test,axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
num_images_to_show = 5
random_indecies = get_random_indecies(len(x_test_images), num_images_to_show)
def plot_images (images,labels,predictions):
    plt.figure(figsize=(10,9))
    for i in range(len(images)):
        plt.subplot(1, len(images), i+1)
        plt.imshow(images[i], cmap='gray')
        plt.title(f"Actual: {labels[i]}\n Predicted: {predictions[i]}")
        plt.axis('off')
    plt.show()

# %%
plot_images(x_test_images[random_indecies], true_classes[random_indecies], predictions_classes[random_indecies])

# %%
# !pip install tensorboard
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=0.4 in c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorboard) (1.80.0)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: packaging in C:\Users\modern\AppData\Roaming\Python\Python312\site-packages (from tensorboard) (25.0)
# Requirement already satisfied: pillow in c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorboard) (12.0.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorboard) (7.34.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorboard) (80.10.2)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tensorboard) (3.0.6)
# Requirement already satisfied: typing-extensions~=4.12 in c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 1.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 0.8/5.5 MB 884.1 kB/s eta 0:00:06
#    ------- -------------------------------- 1.0/5.5 MB 1.0 MB/s eta 0:00:05
#    --------- ------------------------------ 1.3/5.5 MB 1.1 MB/s eta 0:00:04
#    --------- ------------------------------ 1.3/5.5 MB 1.1 MB/s eta 0:00:04
#    --------- ------------------------------ 1.3/5.5 MB 1.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.6/5.5 MB 791.5 kB/s eta 0:00:05
#    ----------- ---------------------------- 1.6/5.5 MB 791.5 kB/s eta 0:00:05
#    --------------- ------------------------ 2.1/5.5 MB 851.1 kB/s eta 0:00:05
#    ----------------- ---------------------- 2.4/5.5 MB 883.0 kB/s eta 0:00:04
#    ------------------ --------------------- 2.6/5.5 MB 938.1 kB/s eta 0:00:04
#    -------------------- ------------------- 2.9/5.5 MB 987.0 kB/s eta 0:00:03
#    ---------------------- ----------------- 3.1/5.5 MB 951.4 kB/s eta 0:00:03
#    ------------------------ --------------- 3.4/5.5 MB 949.8 kB/s eta 0:00:03
#    -------------------------- ------------- 3.7/5.5 MB 982.7 kB/s eta 0:00:02
#    ---------------------------- ----------- 3.9/5.5 MB 1.0 MB/s eta 0:00:02
#    -------------------------------- ------- 4.5/5.5 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 4.7/5.5 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 1.1 MB/s  0:00:04
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
# Installing collected packages: tensorboard-data-server, markdown, tensorboard
#
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    ------------- -------------------------- 1/3 [markdown]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    -------------------------- ------------- 2/3 [tensorboard]
#    ---------------------------------------- 3/3 [tensorboard]
#
# Successfully installed markdown-3.10.2 tensorboard-2.20.0 tensorboard-data-server-0.7.2
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = x_train.reshape(x_train.shape[0], -1)
x_test = x_test.reshape(x_test.shape[0], -1)
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

list_activations = ['sigmoid', 'relu', 'tanh']
list_optimizers = ['adam', 'rmsprop']

i = 1
for activation in list_activations:
    for optimizer in list_optimizers:
        NAME = f'mnist-{activation}-{optimizer}-v{i}'
        print(f"Training session: {NAME}")
        
        tensorboard_callback = TensorBoard(log_dir=f'logs/{NAME}')

        model = tf.keras.Sequential([
            tf.keras.layers.Dense(200, activation=activation, input_shape=(784,)),
            tf.keras.layers.Dense(100, activation=activation),
            tf.keras.layers.Dense(60, activation=activation),
            tf.keras.layers.Dense(10, activation='softmax')
        ])

        model.compile(optimizer=optimizer,
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

        model.fit(x_train, y_train, 
                  epochs=5, 
                  batch_size=64, 
                  validation_split=0.2, 
                  callbacks=[tensorboard_callback])
        
        i += 1
# Out:
# Training session: mnist-sigmoid-adam-v1
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.8137 - loss: 0.7275 - val_accuracy: 0.9243 - val_loss: 0.2817
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.9332 - loss: 0.2384 - val_accuracy: 0.9497 - val_loss: 0.1889
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9534 - loss: 0.1625 - val_accuracy: 0.9582 - val_loss: 0.1458
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9651 - loss: 0.1224 - val_accuracy: 0.9638 - val_loss: 0.1232
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9726 - loss: 0.0965 - val_accuracy: 0.9691 - val_loss: 0.1062
# Training session: mnist-sigmoid-rmsprop-v2
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.7678 - loss: 0.8573 - val_accuracy: 0.8964 - val_loss: 0.3473
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9201 - loss: 0.2783 - val_accuracy: 0.9343 - val_loss: 0.2272
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9424 - loss: 0.1946 - val_accuracy: 0.9491 - val_loss: 0.1754
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9559 - loss: 0.1491 - val_accuracy: 0.9589 - val_loss: 0.1390
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9653 - loss: 0.1196 - val_accuracy: 0.9651 - val_loss: 0.1201
# Training session: mnist-relu-adam-v3
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9193 - loss: 0.2736 - val_accuracy: 0.9543 - val_loss: 0.1520
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9664 - loss: 0.1087 - val_accuracy: 0.9697 - val_loss: 0.1067
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9769 - loss: 0.0756 - val_accuracy: 0.9720 - val_loss: 0.0970
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9834 - loss: 0.0531 - val_accuracy: 0.9750 - val_loss: 0.0935
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9862 - loss: 0.0432 - val_accuracy: 0.9728 - val_loss: 0.0923
# Training session: mnist-relu-rmsprop-v4
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.9166 - loss: 0.2792 - val_accuracy: 0.9563 - val_loss: 0.1516
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.9666 - loss: 0.1113 - val_accuracy: 0.9682 - val_loss: 0.1056
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9775 - loss: 0.0747 - val_accuracy: 0.9716 - val_loss: 0.1043
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9828 - loss: 0.0558 - val_accuracy: 0.9729 - val_loss: 0.0976
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9868 - loss: 0.0435 - val_accuracy: 0.9759 - val_loss: 0.0894
# Training session: mnist-tanh-adam-v5
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9156 - loss: 0.2922 - val_accuracy: 0.9530 - val_loss: 0.1587
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9599 - loss: 0.1331 - val_accuracy: 0.9624 - val_loss: 0.1208
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9725 - loss: 0.0905 - val_accuracy: 0.9678 - val_loss: 0.1094
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9799 - loss: 0.0650 - val_accuracy: 0.9700 - val_loss: 0.0971
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9850 - loss: 0.0485 - val_accuracy: 0.9691 - val_loss: 0.1047
# Training session: mnist-tanh-rmsprop-v6
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9129 - loss: 0.2988 - val_accuracy: 0.9460 - val_loss: 0.1773
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9597 - loss: 0.1368 - val_accuracy: 0.9641 - val_loss: 0.1218
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9716 - loss: 0.0932 - val_accuracy: 0.9679 - val_loss: 0.1102
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9791 - loss: 0.0676 - val_accuracy: 0.9713 - val_loss: 0.0950
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9838 - loss: 0.0515 - val_accuracy: 0.9724 - val_loss: 0.0971

# %%
# !tensorboard --logdir = logs --port = 6006
# Out:
# c:\Users\modern\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorboard\default.py:30: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776152326.207486   15196 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776152338.952410   15196 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# usage: tensorboard [-h] [--helpfull] [--logdir PATH] [--logdir_spec PATH_SPEC]
#                    [--host ADDR] [--bind_all] [--port PORT]
#                    [--reuse_port BOOL] [--load_fast {false,auto,true}]
#                    [--extra_data_server_flags EXTRA_DATA_SERVER_FLAGS]
#                    [--grpc_creds_type {local,ssl,ssl_dev}]
#                    [--grpc_data_provider PORT] [--purge_orphaned_data BOOL]
#                    [--db URI] [--db_import] [--inspect] [--version_tb]
#                    [--tag TAG] [--event_file PATH] [--path_prefix PATH]
#                    [--window_title TEXT] [--max_reload_threads COUNT]
#                    [--reload_interval SECONDS] [--reload_task TYPE]
#                    [--reload_multifile BOOL]
#                    [--reload_multifile_inactive_secs SECONDS]
#                    [--generic_data TYPE]
#                    [--samples_per_plugin SAMPLES_PER_PLUGIN]
#                    [--detect_file_replacement BOOL]
#                    {serve} ...
# tensorboard: error: argument {serve}: invalid choice: 'logs' (choose from 'serve')
