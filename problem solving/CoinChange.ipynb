# %%
from typing import List

class Solution:
    def coinChange(self, coins: List[int], amount: int) -> int:
        dp = [amount + 1] * (amount + 1)
        dp[0] = 0
     
        for i in range(1, amount + 1):
            for coin in coins:
                if i - coin >= 0:
                    dp[i] = min(dp[i], 1 + dp[i - coin])
        
       
        return dp[amount] if dp[amount] != amount + 1 else -1

if __name__ == "__main__":
    sol = Solution()
    print(f"Example 1: {sol.coinChange([1, 2, 5], 11)}")  
    print(f"Example 2: {sol.coinChange([2], 3)}")       
    print(f"Example 3: {sol.coinChange([1], 0)}")
# Out:
# Example 1: 3
# Example 2: -1
# Example 3: 0
