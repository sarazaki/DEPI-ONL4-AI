# %%
def user_info(name , age):
    """
    this function take name and age from user and return again
    :param_1 : take the name of user from input user interface 
    type param_1 : str
    :param_2 : take the age of user from input user interface 
    type param_2 : int

    return : this function will print the name and the age
    rtype: str , int

    """
    return f"my name is {name} , my age is {age}"

# %%
user_info(age =20 , name ="sara")
# Out:
# 'my name is sara , my age is 20'

# %%
def user_info(*name):
    """


    """
    print(name)
    print(type(name))

# %%
user_info("depi","python",5,2.5,True,[1,2,3])
# Out:
# ('depi', 'python', 5, 2.5, True, [1, 2, 3])
# <class 'tuple'>

# %%
x ="sara zaki"
y =20
"{0},{1}".format(x,y)
# Out:
# 'sara zaki,20'

# %%
def user_info(**name):
    print(name)
    print(type(name))
   
user_info(key1=10.5,key2=2)
# Out:
# {'key1': 10.5, 'key2': 2}
# <class 'dict'>

# %%
print(type(user_info))
# Out:
# <class 'function'>

# %%
result = lambda x : x + 10
print(type(result(10)))
# Out:
# <class 'int'>

# %%
result = lambda x : x + 10
print((result(10)))
# Out:
# 20

# %%
function_name = lambda x,y,z:x+y*z
print(function_name(5,10,2))
# Out:
# 25

# %%
function_name = lambda x,y:x+y
print(function_name(5,10))
# Out:
# 15

# %%
def function_1(n):
    return lambda a :a*n

function_2 = function_1(2)
print(function_2(11))
# Out:
# 22

# %%
x =30

# %%
x =20
def fun(x):
      print("inside :", x)
fun (x)
print("outside :", x)
# Out:
# inside : 20
# outside : 20

# %%
x = "global"

def outer_fun():
         x="outer_local"
def inner_fun():
          global x
          x ="changed"
          print("inside inner func",x)
inner_fun()
print("inside outer fun:",x)
outer_fun()
print("outside any fun:", x)
# Out:
# inside inner func changed
# inside outer fun: changed
# outside any fun: changed

# %%
x =int(input())
y =int(input())

try:
    x/y
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 x =int(input())
#       2 y =int(input())
#       4 try:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
try:
    x=10
    y=int(input())
    x/y
except:
    print("division by zero")
finally:
    print("Done!")
# Out:
# division by zero
# Done!

# %%
from random import randint, random
random()
# Out:
# 0.6902113943690031

# %%
import os

# %%
base_dire ="C:/Users/modern/OneDrive/Desktop/DEPI-ONL4-AI/python"

# %%
file_names = os.listdir(base_dire)
type(file_names)
file_names
# Out:
# ['file_handle', 'function.ipynb', 'session 1', 'session 2']

# %%
base_dire = "./tem_dire"
file_name = "txt_1.txt"
file_path = os.path.join(base_dire,file_name)
file_path
# Out:
# './tem_dire\\txt_1.txt'

# %%
file_names = os.listdir(base_dire)
# type(file_names)
file_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 file_names = os.listdir(base_dire)
#       2 # type(file_names)
#       3 file_names
#
# NameError: name 'base_dire' is not defined

# %%
import os
dir = "C:/Users/modern/OneDrive/Desktop/DEPI-ONL4-AI/python/session 3/sara "
if not os.path.exists(dir):
     os.makedirs(dir)

for i in range (20):
        
        inner_path = os.path.join(dir,str(i))
        if not os.path.exists(inner_path):
            os.makedirs(inner_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 10
#       8 inner_path = os.path.join(dir,str(i))
#       9 if not os.path.exists(inner_path):
# ---> 10     os.makedirs(inner_path)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/modern/OneDrive/Desktop/DEPI-ONL4-AI/python/session 3/sara \\0'
