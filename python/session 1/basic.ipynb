# %%
# to print a text with variable 
print("my age =", 30)
# Out:
# my age = 30

# %%
# single line comment

'''  multi line comment
print("hello world")
print("hello world")
print("hello world")
'''

print("hello world")
# Out:
# hello world

# %%
# التلت سطور مش هيتنفذوا لانهم بين multi line comment 
'''
print("amit")
print("learning")
print("python")
'''

print("machine learning")  #السطر اللي هيتنفذ

# السطور اللي تحت دي متعلّقة بعلامة # فبردو مش هتتنفذ
# print("deep learning")
# print("data science")
# print("python")
# Out:
# machine learning

# %%
a = 5
a = 6
# ف الاول قولنا قيمة الa بخمسة وبعدين عايزين نغير قيمته (overwrite)

# %%
print(a)
# Out:
# 6

# %%
print("my name is {0}, my age is {1}".format("amit", 30))
#هنا ال{0} هتتبدل مع كلمة amit , وال{1} هتتبدل مع 30
#هيتم طباعة my name is amit , my age is 30 


print("my age is {1}, my name is {0}".format("amit", 30))
# هنا هيحصل العكس لاننا بدلنا
# Out:
# my name is amit, my age is 30
# my age is 30, my name is amit

# %%
#try to solve 
your_name = "sara zaki"          
your_age = 20
course_name = "machine learning and AI diploma" 

# تكوين الجملة باستخدام f-string
output_text = f"My name is {your_name}, and I am {your_age} years old.I am engaged in learning {course_name}."

# طباعة الجملة
print(output_text)
# Out:
# My name is sara zaki, and I am 20 years old.I am engaged in learning machine learning and AI diploma.

# %%
name = "amit learning" 
print (name[0:4:1])
#0 تعنى البداية يعنى نبدا من حرف الa 
#4 تعنى نتوقف فين وف الجملة هنتوقف عن الspace 
#1 تعنى هنمشي كل كام خطوة
# Out:
# amit

# %%
my_string="0123456789"
print(my_string[-2:-6:-2])


#هنا هنبدا ب-2 دي البداية اللي هي بتساوي رقم 8 
#وهنقف عند -6 اللي هي بتساوي رقم 4 من غير ما ناخده 
#وهنمشي ل خطوتين ناخد رقم ف هناخد ف الاول 8 وبعدين 6 وهنوصل للنهاية من غير ما ناخدها
# Out:
# 86

# %%
name = "AMIT LEARNING" 
print (name.lower())
#الحروف الكابتل هتبقى سمول
# Out:
# amit learning

# %%
name = "amit learning" 
print (name.capitalize())
# جعل اول حرف من كل كلمة كابتل
# Out:
# Amit learning

# %%
name = "amit learning" 
print (name.replace("amit","hello"))
#تبديل كلمة مكان الاخرى
# Out:
# hello learning

# %%
name = "amit learning" 
print (name.upper())
#الحروف السمول هتبقى كابتل
# Out:
# AMIT LEARNING

# %%
name=("depi learning")
upper_txt = name.upper()
print(upper_txt)
# Out:
# DEPI LEARNING

# %%
name="depi learning for machine learning depi"
name.count("depi")
# بيعد كام مرة ذكرت فيها اسم depi
# Out:
# 2

# %%
name="Sara ZAkii"
print(name.swapcase())
#بيخلي الكابتل سمول والسمول كابتل
# Out:
# sARA zaKII

# %%
name="sara mohammed zaki salem"
print(name.endswith("salem"))
#هل الجملة تنتهي بكلمة salem 
# الاجابة نعم ف هيطبع true
# Out:
# True

# %%
name="sara mohammed zaki salem"
print(name.startswith("zaki"))
# هل الجملة بتبدا بكلمة zaki 
#الاجابة لا لانها بتبدا بكلمة sara ف هيطبع false
# Out:
# False

# %%
words = ["my","name", "is", "moahmmed."]
sentence = ' '. join (words)
print (sentence)
#بيجمع الكلمات اللي خزنها ف جملة واحدة
# Out:
# my name is moahmmed.
