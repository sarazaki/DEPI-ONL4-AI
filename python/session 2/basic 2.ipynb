# %%
list_one =[1,2,3,4,"depi","amit","learning"]
print(type(list_one[4]))
# Out:
# <class 'str'>

# %%
list_i =["learning","depi","ml"]
list_i.append("dl")
list_i
# Out:
# ['learning', 'depi', 'ml', 'dl']

# %%
list_i.insert(0,"data")
list_i
# Out:
# ['data', 'learning', 'depi', 'ml', 'dl']

# %%
list_2 =[1,2,3]
list_3 =[4,5,6]
list_4 = list_2 + list_3
list_2.extend(list_3)
list_2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_new =["depi","learning","python"]
list_new.remove("depi")
print(list_new)
# Out:
# ['learning', 'python']

# %%
list_1 =[1,2,3]
list_2 =[4,5,6]
list_3 =[7,8,9]
matrix = [list_1,list_2,list_3]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
my_list = ['one','two','three',4,5]
my_list *2
# Out:
# ['one', 'two', 'three', 4, 5, 'one', 'two', 'three', 4, 5]

# %%
a = 200
b = 33
if b > a :
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x = 5
y = 10
if x>0 and y>0 :
    print("positive numbers")
# Out:
# positive numbers

# %%
x = 5
result ="Even" if x % 2 == 0 else "Odd"
print(result)
# Out:
# Odd
